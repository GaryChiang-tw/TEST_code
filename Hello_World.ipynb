# %% [markdown]
# <a href="https://colab.research.google.com/github/GaryChiang-tw/TEST_HelloWorld/blob/main/Hello_World.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, GitHub!")
print("Hello, GitHub!")
# Out:
# Hello, GitHub!
# Hello, GitHub!
